# %% [markdown]
# # Taller 05
#
# ## Nombre: Isaac Gonzalez
# ## Métodos Númericos
#
# ---

# %% [markdown]
# 1. Comprobar gráficamente

# %%
import numpy as np
import matplotlib.pyplot as plt

x1, y1 = 5.4, 3.2
x2, y2 = 9.5, 0.7
x3, y3 = 12.3, -3.6
m, b = -0.9578, 8.584

def ec_1(x):
    return m * x + b

xs = np.linspace(min(x1, x2, x3) - 1, max(x1, x2, x3) + 1, 300)
ys = ec_1(xs)

plt.figure(figsize=(8, 5))
plt.plot(xs, ys, label=f"y = {m}x + {b}", color='tab:blue')
plt.scatter([x1, x2, x3], [y1, y2, y3], color='red', zorder=5, label='Puntos')
for xi, yi in [(x1, y1), (x2, y2), (x3, y3)]:
    plt.annotate(f"({xi}, {yi})", (xi, yi), textcoords="offset points", xytext=(6, 6), fontsize=9)
plt.axhline(0, color='black', linewidth=0.6)
plt.axvline(0, color='black', linewidth=0.6)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Minimos cuadrados")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 2.

# %%
# Derivadas parciales para regresión lineal
# ####################################################################
def der_parcial_1(xs: list, ys: list) -> tuple[float, float, float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 1 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """

    # coeficiente del término independiente
    c_ind = sum(ys)

    # coeficiente del parámetro 1
    c_1 = sum(xs)

    # coeficiente del parámetro 0
    c_0 = len(xs)

    return (c_1, c_0, c_ind)


def der_parcial_0(xs: list, ys: list) -> tuple[float, float, float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 0 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """
    c_1 = 0
    c_0 = 0
    c_ind = 0
    for xi, yi in zip(xs, ys):
        # coeficiente del término independiente
        c_ind += xi * yi

        # coeficiente del parámetro 1
        c_1 += xi * xi

        # coeficiente del parámetro 0
        c_0 += xi

    return (c_1, c_0, c_ind)

# %%
from src import ajustar_min_cuadrados

# UTILICE:
ajustar_min_cuadrados([1, 4, 5, 6], [2, 3, 5, 7], [der_parcial_1, der_parcial_0])
# Out:
# [12-15 21:25:51][INFO] Se ajustarán 2 parámetros.
# array([0.92857143, 0.53571429])

# %%
from src import ajustar_min_cuadrados

ajustar_min_cuadrados([3.38,
0.35,
2.07,
-0.45,
-0.55,
-1.06,
-2.77,
3.08,
-3.98,
-5,  
-3.18,
-1.96,
2.37,
-1.66,
4.09], [-0.04,
1.28,
0.65,
2.18,
1.70,
1.96,
3.36,
0.18,
3.35,
4.16,
2.95,
2.34,
0.38,
1.75,
-1.06], [der_parcial_1, der_parcial_0])
# Out:
# [12-15 21:25:51][INFO] Se ajustarán 2 parámetros.
# array([-0.50323259,  1.49919762])

# %%
import matplotlib.pyplot as plt
import numpy as np

xs = [ 3.38,
0.35,
2.07,
-0.45,
-0.55,
-1.06,
-2.77,
3.08,
-3.98,
-5, 
-3.18,
-1.96,
2.37,
-1.66,
4.09]

ys = [-0.04,
1.28,
0.65,
2.18,
1.70,
1.96,
3.36,
0.18,
3.35,
4.16,
2.95,
2.34,
0.38,
1.75,
-1.06]

m,b = -0.50323259, 1.49919762
xs0 = np.linspace(-4, 13, 200)


def s_0(x):
    return m * x + b


plt.figure(figsize=(8, 5))
for xi, yi in zip(xs, ys):
    plt.scatter([xi], [yi], color='red')
    


plt.plot(xs0, s_0(xs0), label='s_0(x)', color='blue')

plt.axhline(0, color='black', linewidth=1)
plt.grid(True, linestyle='--', alpha=0.6)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Mínimos cuadrados')
plt.legend()
plt.xlim(-4, 14)
plt.ylim(-4, 10)
plt.show()

# %% [markdown]
# 3.

# %%
from src import ajustar_min_cuadrados

from src import ajustar_min_cuadrados

ajustar_min_cuadrados([
    3.38, 0.35, 2.07, -0.45, -0.56, -1.06, -2.78, 3.08,
    -3.99, -5.00, -3.18, -1.97, 2.37, -1.67, 4.09,
    -4.60, 2.68, 2.78, -3.79, -1.87
], [
    15.65, -11.20, -4.00, 18.03, 7.94, 15.32, -4.40, 1.39,
    -11.92, -90.24, 6.92, 28.35, -2.41, -5.47, 35.91,
    -55.53, 0.77, 4.79, -27.05, 2.85
], [der_parcial_1, der_parcial_0])
# Out:
# [12-15 21:25:51][INFO] Se ajustarán 2 parámetros.
# array([ 5.68666556, -0.83754722])

# %%
import matplotlib.pyplot as plt
import numpy as np

xs = [
    3.38, 0.35, 2.07, -0.45, -0.56, -1.06, -2.78, 3.08,
    -3.99, -5.00, -3.18, -1.97, 2.37, -1.67, 4.09,
    -4.60, 2.68, 2.78, -3.79, -1.87
]

ys = [
    15.65, -11.20, -4.00, 18.03, 7.94, 15.32, -4.40, 1.39,
    -11.92, -90.24, 6.92, 28.35, -2.41, -5.47, 35.91,
    -55.53, 0.77, 4.79, -27.05, 2.85
]

m,b = 5.68666556, -0.83754722
xs0 = np.linspace(-4, 13, 200)


def s_0(x):
    return m * x + b


plt.figure(figsize=(8, 5))
for xi, yi in zip(xs, ys):
    plt.scatter([xi], [yi], color='red')
    


plt.plot(xs0, s_0(xs0), label='s_0(x)', color='blue')

plt.axhline(0, color='black', linewidth=1)
plt.grid(True, linestyle='--', alpha=0.6)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Mínimos cuadrados')
plt.legend()
plt.xlim(-5, 10)
plt.ylim(-80, 40)
plt.show()

# %% [markdown]
# 4.

# %%
def der_parcial_a(xs: list, ys: list) -> tuple[float, float, float, float, float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 0 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """
    c_3=0
    c_2=0
    c_1 = 0
    c_0 = 0
    c_ind = 0
    for xi, yi in zip(xs, ys):
        c_ind += (xi**3) * yi

        c_3 += xi**6
        
        c_2 += xi**5
        
        c_1 += xi**4

        c_0 += xi**3

    return (c_3, c_2, c_1, c_0, c_ind)




def der_parcial_b(xs: list, ys: list) -> tuple[float, float, float, float, float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 0 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """
    c_3=0
    c_2=0
    c_1 = 0
    c_0 = 0
    c_ind = 0
    for xi, yi in zip(xs, ys):
        
        c_ind += (xi**2) * yi

        c_3 += xi**5
        
        c_2 += xi**4
        
        c_1 += xi**3

        c_0 += xi**2

    return (c_3, c_2, c_1, c_0, c_ind)



def der_parcial_c(xs: list, ys: list) -> tuple[float, float, float, float, float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 0 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """
    c_3=0
    c_2=0
    c_1 = 0
    c_0 = 0
    c_ind = 0
    for xi, yi in zip(xs, ys):
        c_ind += (xi) * yi

        c_3 += xi**4
        
        c_2 += xi**3
        
        c_1 += xi**2

        c_0 += xi

    return (c_3, c_2, c_1, c_0, c_ind)

def der_parcial_d(xs: list, ys: list) -> tuple[float, float, float, float, float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 0 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """
    c_3=0
    c_2=0
    c_1 = 0
    c_0 = 0
    c_ind = 0
    for xi, yi in zip(xs, ys):
        c_ind += yi

        c_3 += xi**3
        
        c_2 += xi**2
        
        c_1 += xi

        c_0 += 1

    return (c_3, c_2, c_1, c_0, c_ind)

# %%
xs = [
    3.38,
    0.35,
    2.07,
    -0.45,
    -0.56,
    -1.06,
    -2.78,
    3.08,
    -3.99,
    -5.00,
    -3.18,
    -1.97,
    2.37,
    -1.67,
    4.09,
    -4.60,
    2.68,
    2.78,
    -3.79,
    -1.87,
]
ys = [
    15.65,
    -11.20,
    -4.00,
    18.03,
    7.94,
    15.32,
    -4.40,
    1.39,
    -11.92,
    -90.24,
    6.92,
    28.35,
    -2.41,
    -5.47,
    35.91,
    -55.53,
    0.77,
    4.79,
    -27.05,
    2.85,
]

a, b, c, d = ajustar_min_cuadrados(
    xs,
    ys,
    gradiente=[der_parcial_a, der_parcial_b, der_parcial_c, der_parcial_d],
)

print(f"a: {a}, b: {b}, c: {c}, d: {d}")

plt.figure(figsize=(9, 5))


plt.scatter(xs, ys, color="red", label="Data points", s=20)


x_line = np.linspace(min(xs), max(xs), 100)
y_line = a * x_line**3 + b * x_line**2 + c * x_line + d
plt.plot(
    x_line,
    y_line,
    color="blue",
    label=f"y = {a:.2f}x³ + {b:.2f}x² + {c:.2f}x + {d:.2f}"
)

plt.xlabel("x")
plt.ylabel("y")
plt.title("Linear Regression")
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# [12-15 21:25:52][INFO] Se ajustarán 4 parámetros.
# a: 1.0449779168246989, b: 0.03132740575354249, c: -8.88066397007552, d: 2.762289919876909
